# %%
for i in range(1, 25):
    print(f'./waf --run SA_{i}; ', end='')

for i in range(1, 25):
    print(f'./waf --run HDSO_{i}; ', end='')
# Out:
# ./waf --run SA_1; ./waf --run SA_2; ./waf --run SA_3; ./waf --run SA_4; ./waf --run SA_5; ./waf --run SA_6; ./waf --run SA_7; ./waf --run SA_8; ./waf --run SA_9; ./waf --run SA_10; ./waf --run SA_11; ./waf --run SA_12; ./waf --run SA_13; ./waf --run SA_14; ./waf --run SA_15; ./waf --run SA_16; ./waf --run SA_17; ./waf --run SA_18; ./waf --run SA_19; ./waf --run SA_20; ./waf --run SA_21; ./waf --run SA_22; ./waf --run SA_23; ./waf --run SA_24; ./waf --run HDSO_1; ./waf --run HDSO_2; ./waf --run HDSO_3; ./waf --run HDSO_4; ./waf --run HDSO_5; ./waf --run HDSO_6; ./waf --run HDSO_7; ./waf --run HDSO_8; ./waf --run HDSO_9; ./waf --run HDSO_10; ./waf --run HDSO_11; ./waf --run HDSO_12; ./waf --run HDSO_13; ./waf --run HDSO_14; ./waf --run HDSO_15; ./waf --run HDSO_16; ./waf --run HDSO_17; ./waf --run HDSO_18; ./waf --run HDSO_19; ./waf --run HDSO_20; ./waf --run HDSO_21; ./waf --run HDSO_22; ./waf --run HDSO_23; ./waf --run HDSO_24;
